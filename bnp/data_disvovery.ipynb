# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('train.csv')

# %%
train.shape
# Out:
# (114321, 133)

# %%
train.head()
# Out:
#    ID  target        v1        v2 v3        v4         v5        v6        v7  \
# 0   3       1  1.335739  8.727474  C  3.921026   7.915266  2.599278  3.176895
# 1   4       1       NaN       NaN  C       NaN   9.191265       NaN       NaN
# 2   5       1  0.943877  5.310079  C  4.410969   5.326159  3.979592  3.928571
# 3   6       1  0.797415  8.304757  C  4.225930  11.627438  2.097700  1.987549
# 4   8       1       NaN       NaN  C       NaN        NaN       NaN       NaN
#
#          v8    ...         v122      v123      v124  v125      v126      v127  \
# 0  0.012941    ...     8.000000  1.989780  0.035754    AU  1.804126  3.113719
# 1  2.301630    ...          NaN       NaN  0.598896    AF       NaN       NaN
# 2  0.019645    ...     9.333333  2.477596  0.013452    AE  1.773709  3.922193
# 3  0.171947    ...     7.018256  1.812795  0.002267    CJ  1.415230  2.954381
# 4       NaN    ...          NaN       NaN       NaN     Z       NaN       NaN
#
# ...

# %%
plt.figure(figsize=(10, 10))
train0 = train.loc[(train.target == 0).values, ['v1', 'v2']].dropna()
train1 = train.loc[(train.target == 1).values, ['v1', 'v2']].dropna()
plt.scatter(x=train0.v1, y=train0.v2)
plt.scatter(x=train1.v1, y=train1.v2, c='r', alpha=.5)

# %%
plt.figure(figsize=(10, 10))
train0 = train.loc[(train.target == 0).values, ['v1', 'v4']].dropna()
train1 = train.loc[(train.target == 1).values, ['v1', 'v4']].dropna()
plt.scatter(x=train0.v1, y=train0.v4)
plt.scatter(x=train1.v1, y=train1.v4, c='r', alpha=.5)

# %%
plt.figure(figsize=(10, 10))
train0 = train.loc[(train.target == 0).values, ['v1', 'v5']].dropna()
train1 = train.loc[(train.target == 1).values, ['v1', 'v5']].dropna()
plt.scatter(x=train0.v1, y=train0.v5)
plt.scatter(x=train1.v1, y=train1.v5, c='r', alpha=.1)

# %%
plt.figure(figsize=(10, 10))
train0 = train.loc[(train.target == 0).values, ['v1', 'v6']].dropna()
train1 = train.loc[(train.target == 1).values, ['v1', 'v6']].dropna()
plt.scatter(x=train0.v1, y=train0.v6)
plt.scatter(x=train1.v1, y=train1.v6, c='r', alpha=.1)

# %%
plt.figure(figsize=(10, 10))
train0 = train.loc[(train.target == 0).values, ['v1', 'v6']].dropna()
train1 = train.loc[(train.target == 1).values, ['v1', 'v6']].dropna()
plt.scatter(x=train0.v1, y=train0.v6)
plt.scatter(x=train1.v1, y=train1.v6, c='r', alpha=.1)

# %%
plt.figure(figsize=(10, 10))
v1 = 'v1'
v2 = 'v7'
train0 = train.loc[(train.target == 0).values, [v1, v2]].dropna()
train1 = train.loc[(train.target == 1).values, [v1, v2]].dropna()
plt.scatter(x=train0.loc[:, v1], y=train0.loc[:, v2])
plt.scatter(x=train1.loc[:, v1], y=train1.loc[:, v2], c='r', alpha=.1)

# %%
plt.figure(figsize=(10, 10))
v1 = 'v1'
v2 = 'v8'
train0 = train.loc[(train.target == 0).values, [v1, v2]].dropna()
train1 = train.loc[(train.target == 1).values, [v1, v2]].dropna()
plt.scatter(x=train0.loc[:, v1], y=train0.loc[:, v2])
plt.scatter(x=train1.loc[:, v1], y=train1.loc[:, v2], c='r', alpha=.1)

# %%
plt.figure(figsize=(10, 10))
v1 = 'v1'
v2 = 'v9'
train0 = train.loc[(train.target == 0).values, [v1, v2]].dropna()
train1 = train.loc[(train.target == 1).values, [v1, v2]].dropna()
plt.scatter(x=train0.loc[:, v1], y=train0.loc[:, v2])
plt.scatter(x=train1.loc[:, v1], y=train1.loc[:, v2], c='r', alpha=.1)

# %%
plt.figure(figsize=(10, 10))
v1 = 'v1'
v2 = 'v9'
train0 = train.loc[(train.target == 0).values, [v1, v2]].dropna()
train1 = train.loc[(train.target == 1).values, [v1, v2]].dropna()
plt.scatter(x=train0.loc[:, v1], y=train0.loc[:, v2])
plt.scatter(x=train1.loc[:, v1], y=train1.loc[:, v2], c='r', alpha=.1)

# %%
plt.figure(figsize=(10, 10))
v1 = 'v1'
v2 = 'v10'
train0 = train.loc[(train.target == 0).values, [v1, v2]].dropna()
train1 = train.loc[(train.target == 1).values, [v1, v2]].dropna()
plt.scatter(x=train0.loc[:, v1], y=train0.loc[:, v2])
plt.scatter(x=train1.loc[:, v1], y=train1.loc[:, v2], c='r', alpha=.1)

# %%
plt.figure(figsize=(10, 10))
v1 = 'v1'
v2 = 'v11'
train0 = train.loc[(train.target == 0).values, [v1, v2]].dropna()
train1 = train.loc[(train.target == 1).values, [v1, v2]].dropna()
plt.scatter(x=train0.loc[:, v1], y=train0.loc[:, v2])
plt.scatter(x=train1.loc[:, v1], y=train1.loc[:, v2], c='r', alpha=.1)

# %%
plt.figure(figsize=(10, 10))
v1 = 'v1'
v2 = 'v12'
train0 = train.loc[(train.target == 0).values, [v1, v2]].dropna()
train1 = train.loc[(train.target == 1).values, [v1, v2]].dropna()
plt.scatter(x=train0.loc[:, v1], y=train0.loc[:, v2])
plt.scatter(x=train1.loc[:, v1], y=train1.loc[:, v2], c='r', alpha=.1)

# %%
plt.figure(figsize=(10, 10))
v1 = 'v1'
v2 = 'v13'
train0 = train.loc[(train.target == 0).values, [v1, v2]].dropna()
train1 = train.loc[(train.target == 1).values, [v1, v2]].dropna()
plt.scatter(x=train0.loc[:, v1], y=train0.loc[:, v2])
plt.scatter(x=train1.loc[:, v1], y=train1.loc[:, v2], c='r', alpha=.1)

# %%
plt.figure(figsize=(10, 10))
v1 = 'v1'
v2 = 'v14'
train0 = train.loc[(train.target == 0).values, [v1, v2]].dropna()
train1 = train.loc[(train.target == 1).values, [v1, v2]].dropna()
plt.scatter(x=train0.loc[:, v1], y=train0.loc[:, v2])
plt.scatter(x=train1.loc[:, v1], y=train1.loc[:, v2], c='r', alpha=.1)

# %%
train_by_target = train.groupby('target')

# %%
train.loc[:, ['target', 'v1']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v2']].boxplot(by='target')

# %%
train_by_target['v3'].value_counts().unstack(level=0).plot(kind='bar', logy=True)

# %%
train.loc[:, ['target', 'v4']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v5']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v5']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v6']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v7']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v8']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v9']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v10']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v11']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v12']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v13']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v14']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v15']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v16']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v17']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v18']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v19']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v20']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v21']].boxplot(by='target')

# %%
train['v22'].value_counts().shape
# Out:
# (18210,)

# %%
train.loc[:, ['target', 'v23']].boxplot(by='target')

# %%
train_by_target['v24'].value_counts().unstack(level=0).plot(kind='bar', logy=True)

# %%
train.loc[:, ['target', 'v25']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v26']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v27']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v28']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v29']].boxplot(by='target')

# %%
train_by_target['v30'].value_counts().unstack(level=0).plot(kind='bar', logy=True)

# %%
train_by_target['v31'].value_counts().unstack(level=0).plot(kind='bar', logy=True)

# %%
train.loc[:, ['target', 'v32']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v33']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v34']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v35']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v36']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v37']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v38']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v39']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v40']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v41']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v42']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v43']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v44']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v45']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v46']].boxplot(by='target')

# %%
train_by_target['v47'].value_counts().unstack(level=0).plot(kind='bar', logy=True)

# %%
train.loc[:, ['target', 'v48']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v49']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v49']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v50']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v51']].boxplot(by='target')

# %%
train_by_target['v52'].value_counts().unstack(level=0).plot(kind='bar', logy=True)

# %%
train.loc[:, ['target', 'v53']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v54']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v55']].boxplot(by='target')

# %%
train_by_target['v56'].head()
# Out:
# 0      DI
# 1      DY
# 2      AS
# 3      BW
# 4     NaN
# 5      DX
# 6      AS
# 8      AF
# 12     BW
# 29    NaN
# Name: v56, dtype: object

# %%
train.loc[:, ['target', 'v57']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v58']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v59']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v60']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v61']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v62']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v63']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v64']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v65']].boxplot(by='target')

# %%
train_by_target['v66'].value_counts().unstack(level=0).plot(kind='bar', logy=True)

# %%
train.loc[:, ['target', 'v67']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v68']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v69']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v70']].boxplot(by='target')

# %%
train_by_target['v71'].value_counts().unstack(level=0).plot(kind='bar', logy=True)

# %%
train.loc[:, ['target', 'v72']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v73']].boxplot(by='target')

# %%
train_by_target['v74'].value_counts().unstack(level=0).plot(kind='bar', logy=True)

# %%
train_by_target['v75'].value_counts().unstack(level=0).plot(kind='bar', logy=True)

# %%
train.loc[:, ['target', 'v76']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v77']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v78']].boxplot(by='target')

# %%
train_by_target['v79'].value_counts().unstack(level=0).plot(kind='bar', logy=True)

# %%
train.loc[:, ['target', 'v80']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v81']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v82']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v83']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v84']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v85']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v86']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v87']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v88']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v89']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v90']].boxplot(by='target')

# %%
train_by_target['v91'].value_counts().unstack(level=0).plot(kind='bar', logy=True)

# %%
train.loc[:, ['target', 'v92']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v93']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v94']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v95']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v96']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v97']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v98']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v99']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v100']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v101']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v102']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v103']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v104']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v105']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v106']].boxplot(by='target')

# %%
train_by_target['v107'].value_counts().unstack(level=0).plot(kind='bar', logy=True)

# %%
train.loc[:, ['target', 'v108']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v108']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v109']].boxplot(by='target')

# %%
train_by_target['v110'].value_counts().unstack(level=0).plot(kind='bar', logy=True)

# %%
train.loc[:, ['target', 'v111']].boxplot(by='target')

# %%
train_by_target['v112'].value_counts().unstack(level=0).plot(kind='bar', logy=True)

# %%
train_by_target['v113'].value_counts().unstack(level=0).plot(kind='bar', logy=True)

# %%
train.loc[:, ['target', 'v114']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v115']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v116']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v117']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v118']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v119']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v120']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v121']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v122']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v123']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v124']].boxplot(by='target')

# %%
train_by_target['v125'].value_counts().unstack(level=0).plot(kind='bar', logy=True)

# %%
train.loc[:, ['target', 'v126']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v127']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v128']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v129']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v130']].boxplot(by='target')

# %%
train.loc[:, ['target', 'v131']].boxplot(by='target')
